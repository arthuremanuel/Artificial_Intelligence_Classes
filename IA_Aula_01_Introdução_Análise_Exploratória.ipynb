# %% [markdown]
# <a href="https://colab.research.google.com/github/arthuremanuel/Artificial_Intelligence_Classes/blob/main/IA_Aula_01_Introdu%C3%A7%C3%A3o_An%C3%A1lise_Explorat%C3%B3ria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Este exemplo busca investigar a relação entre satisfação pessoal e bem-estar por país (medida pelo índice Better Life Index) e a renda, isto é, o Produto Interno Bruto de um país (medido pelo Gross Domestic Product per capta).
#
#
# *   Um país rico possui apresenta maior bem-estar pessoal?
#
#
#
# Links <br>
# CSV - Better Life Index <br>
# 2023 - https://stats.oecd.org/index.aspx?DataSetCode=BLI <br>
# CSV - GDP Per Capta<br>
# Atual - https://data.worldbank.org/indicator/NY.GDP.PCAP.CD?most_recent_value_desc=true <br>
# 2018 - https://www.kaggle.com/datasets/nitishabharathi/gdp-per-capita-all-countries?resource=download

# %% [markdown]
# # Pandas
# * Pandas is a Python library used for working with data sets.
# * It has functions for analyzing, cleaning, exploring, and manipulating big amounts of data.
#  * Is there a correlation between two or more columns?
#  * What is average value?
#  * Max value?
#  * Min value?
#
# **DataFrame**
#
# * A data frame is a structured representation of data.

# %%
import pandas as pd
#Better Life Index
df_BLI = pd.read_csv('BLI_14032023154226674.csv', sep = ";")
df_BLI
# Out:
#      LOCATION         Country INDICATOR                          Indicator  \
# 0         AUS       Australia   JE_LMIS           Labour market insecurity
# 1         AUT         Austria   JE_LMIS           Labour market insecurity
# 2         BEL         Belgium   JE_LMIS           Labour market insecurity
# 3         CAN          Canada   JE_LMIS           Labour market insecurity
# 4         CZE  Czech Republic   JE_LMIS           Labour market insecurity
# ...       ...             ...       ...                                ...
# 2364      CRI      Costa Rica   PS_REPH                      Homicide rate
# 2365      CRI      Costa Rica   PS_REPH                      Homicide rate
# 2366      CRI      Costa Rica   WL_EWLH  Employees working very long hours
# 2367      CRI      Costa Rica   WL_EWLH  Employees working very long hours
# 2368      CRI      Costa Rica   WL_EWLH  Employees working very long hours
#
#      MEASURE Measure INEQUALITY Inequality Unit Code        Unit  \
# ...

# %%
#You can find out what categories exist and how many districts belong to each category by using the value_counts() method:
df_BLI.head()
# Out:
#   LOCATION         Country INDICATOR                 Indicator MEASURE  \
# 0      AUS       Australia   JE_LMIS  Labour market insecurity       L
# 1      AUT         Austria   JE_LMIS  Labour market insecurity       L
# 2      BEL         Belgium   JE_LMIS  Labour market insecurity       L
# 3      CAN          Canada   JE_LMIS  Labour market insecurity       L
# 4      CZE  Czech Republic   JE_LMIS  Labour market insecurity       L
#
#   Measure INEQUALITY Inequality Unit Code        Unit  PowerCode Code  \
# 0   Value        TOT      Total        PC  Percentage               0
# 1   Value        TOT      Total        PC  Percentage               0
# 2   Value        TOT      Total        PC  Percentage               0
# 3   Value        TOT      Total        PC  Percentage               0
# 4   Value        TOT      Total        PC  Percentage               0
#
#   PowerCode  Reference Period Code  Reference Period  Value  Flag Codes  Flags
# ...

# %%
df_BLI["INEQUALITY"].value_counts()
# Out:
# TOT    935
# MN     558
# WMN    558
# HGH    159
# LW     159
# Name: INEQUALITY, dtype: int64

# %%
df_BLI.columns
# Out:
# Index(['LOCATION', 'Country', 'INDICATOR', 'Indicator', 'MEASURE', 'Measure',
#        'INEQUALITY', 'Inequality', 'Unit Code', 'Unit', 'PowerCode Code',
#        'PowerCode', 'Reference Period Code', 'Reference Period', 'Value',
#        'Flag Codes', 'Flags'],
#       dtype='object')

# %%
df_BLI.describe()
# Out:
#        PowerCode Code  Reference Period Code  Reference Period          Value  \
# count          2369.0                    0.0               0.0    2369.000000
# mean              0.0                    NaN               NaN    5299.220612
# std               0.0                    NaN               NaN   41894.336828
# min               0.0                    NaN               NaN       0.000000
# 25%               0.0                    NaN               NaN       7.100000
# 50%               0.0                    NaN               NaN      66.000000
# 75%               0.0                    NaN               NaN      88.000000
# max               0.0                    NaN               NaN  941162.000000
#
#        Flag Codes  Flags
# count         0.0    0.0
# mean          NaN    NaN
# std           NaN    NaN
# min           NaN    NaN
# 25%           NaN    NaN
# 50%           NaN    NaN
# 75%           NaN    NaN
# max           NaN    NaN

# %%
df_BLI.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2369 entries, 0 to 2368
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   LOCATION               2369 non-null   object
#  1   Country                2369 non-null   object
#  2   INDICATOR              2369 non-null   object
#  3   Indicator              2369 non-null   object
#  4   MEASURE                2369 non-null   object
#  5   Measure                2369 non-null   object
#  6   INEQUALITY             2369 non-null   object
#  7   Inequality             2369 non-null   object
#  8   Unit Code              2369 non-null   object
#  9   Unit                   2369 non-null   object
#  10  PowerCode Code         2369 non-null   int64
#  11  PowerCode              2369 non-null   object
#  12  Reference Period Code  0 non-null      float64
#  13  Reference Period       0 non-null      float64
# ...

# %%
# Filtrando (Where)
# Necessário conhecimento do domínio
df_BLI = df_BLI [ df_BLI['INEQUALITY'] == 'TOT']   
df_BLI = df_BLI [ df_BLI['Indicator'] == 'Life satisfaction' ]
df_BLI
# Out:
#      LOCATION          Country INDICATOR          Indicator MEASURE Measure  \
# 1722      AUS        Australia   SW_LIFS  Life satisfaction       L   Value
# 1723      AUT          Austria   SW_LIFS  Life satisfaction       L   Value
# 1724      BEL          Belgium   SW_LIFS  Life satisfaction       L   Value
# 1725      CAN           Canada   SW_LIFS  Life satisfaction       L   Value
# 1726      CZE   Czech Republic   SW_LIFS  Life satisfaction       L   Value
# 1727      DNK          Denmark   SW_LIFS  Life satisfaction       L   Value
# 1728      FIN          Finland   SW_LIFS  Life satisfaction       L   Value
# 1729      FRA           France   SW_LIFS  Life satisfaction       L   Value
# 1730      DEU          Germany   SW_LIFS  Life satisfaction       L   Value
# 1731      GRC           Greece   SW_LIFS  Life satisfaction       L   Value
# 1732      HUN          Hungary   SW_LIFS  Life satisfaction       L   Value
# ...

# %%
df_BLI = df_BLI[['LOCATION','Country','Value']]
df_BLI
# Out:
#      LOCATION          Country  Value
# 1722      AUS        Australia    7.1
# 1723      AUT          Austria    7.2
# 1724      BEL          Belgium    6.8
# 1725      CAN           Canada    7.0
# 1726      CZE   Czech Republic    6.9
# 1727      DNK          Denmark    7.5
# 1728      FIN          Finland    7.9
# 1729      FRA           France    6.7
# 1730      DEU          Germany    7.3
# 1731      GRC           Greece    5.8
# 1732      HUN          Hungary    6.0
# 1733      ISL          Iceland    7.6
# 1734      IRL          Ireland    7.0
# 1735      ITA            Italy    6.5
# 1736      JPN            Japan    6.1
# 1737      KOR            Korea    5.8
# 1738      LUX       Luxembourg    7.4
# 1739      MEX           Mexico    6.0
# 1740      NLD      Netherlands    7.5
# 1741      NZL      New Zealand    7.3
# 1742      NOR           Norway    7.3
# 1743      POL           Poland    6.1
# 1744      PRT         Portugal    5.8
# 1745      SVK  Slovak Republic    6.5
# ...

# %%
df_BLI.describe()
# Out:
#            Value
# count  42.000000
# mean    6.602381
# std     0.716526
# min     4.900000
# 25%     6.100000
# 50%     6.600000
# 75%     7.200000
# max     7.900000

# %%
df_BLI.sort_values("Value",ascending=False, inplace = True)
df_BLI
# Out:
# <ipython-input-11-3d8d49798d4f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_BLI.sort_values("Value",ascending=False, inplace = True)
#      LOCATION          Country  Value
# 1728      FIN          Finland    7.9
# 1733      ISL          Iceland    7.6
# 1748      CHE      Switzerland    7.5
# 1727      DNK          Denmark    7.5
# 1740      NLD      Netherlands    7.5
# 1738      LUX       Luxembourg    7.4
# 1747      SWE           Sweden    7.3
# 1742      NOR           Norway    7.3
# 1741      NZL      New Zealand    7.3
# 1730      DEU          Germany    7.3
# 1755      ISR           Israel    7.2
# 1723      AUT          Austria    7.2
# 1722      AUS        Australia    7.1
# 1734      IRL          Ireland    7.0
# 1725      CAN           Canada    7.0
# ...

# %%
#GDP Per Capta
#https://data.worldbank.org/indicator/NY.GDP.PCAP.CD?most_recent_value_desc=true -- 14/03/2023
#https://www.kaggle.com/datasets/nitishabharathi/gdp-per-capita-all-countries?resource=download
df_GDP = pd.read_csv("/content/GDP.csv", sep = ",")
df_GDP
# Out:
#          Country  Country Code          1990          1991          1992  \
# 0           Aruba          ABW  24101.109430  25870.755940  26533.343900
# 1     Afghanistan          AFG           NaN           NaN           NaN
# 2          Angola          AGO   3089.683369   3120.356148   2908.160798
# 3         Albania          ALB   2549.473022   1909.114038   1823.307673
# 4      Arab World          ARB   6808.206995   6872.273195   7255.328362
# ..            ...          ...           ...           ...           ...
# 255        Kosovo          XKX           NaN           NaN           NaN
# 256   Yemen, Rep.          YEM   2223.028771   2325.263661   2443.920401
# 257  South Africa          ZAF   6424.502215   6414.057923   6261.716184
# 258        Zambia          ZMB   1517.926292   1528.781247   1499.340446
# 259      Zimbabwe          ZWE   1829.677575   1949.732966   1777.843425
#
#              1993          1994          1995          1996          1997  \
# ...

# %%
df_GDP.columns
# Out:
# Index(['Country ', 'Country Code', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018', '2019'],
#       dtype='object')

# %%
df_GDP = df_GDP[['Country Code','Country ','2018']]
df_GDP
# Out:
#     Country Code      Country           2018
# 0            ABW         Aruba           NaN
# 1            AFG   Afghanistan   1955.006208
# 2            AGO        Angola   6452.355165
# 3            ALB       Albania  13364.155400
# 4            ARB    Arab World  17570.137600
# ..           ...           ...           ...
# 255          XKX        Kosovo  11348.363450
# 256          YEM   Yemen, Rep.   2575.126385
# 257          ZAF  South Africa  13686.882360
# 258          ZMB        Zambia   4223.906936
# 259          ZWE      Zimbabwe   3029.793005
#
# [260 rows x 3 columns]

# %%
df_GDP.describe()
# Out:
#                 2018
# count     231.000000
# mean    21134.599621
# std     21946.871195
# min       744.182072
# 25%      4953.221142
# 50%     14623.674050
# 75%     29899.971315
# max    126898.425900

# %%
df_GDP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  260 non-null    object
#  1   Country       260 non-null    object
#  2   2018          231 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 6.2+ KB

# %%
#Junção de ambos DFs por código de páis
df = df_BLI.set_index('LOCATION').join(df_GDP.set_index('Country Code'), how = 'inner')
df
# Out:
#              Country  Value            Country           2018
# FIN          Finland    7.9             Finland   48416.93603
# ISL          Iceland    7.6             Iceland   57303.06078
# CHE      Switzerland    7.5         Switzerland   68060.94105
# DNK          Denmark    7.5             Denmark   55671.16527
# NLD      Netherlands    7.5         Netherlands   56328.94114
# LUX       Luxembourg    7.4          Luxembourg  113337.42050
# SWE           Sweden    7.3              Sweden   53208.88436
# NOR           Norway    7.3              Norway   65510.58527
# NZL      New Zealand    7.3         New Zealand   41005.42087
# DEU          Germany    7.3             Germany   53074.54012
# ISR           Israel    7.2              Israel   39919.16965
# AUT          Austria    7.2             Austria   55454.68929
# AUS        Australia    7.1           Australia   51663.36509
# IRL          Ireland    7.0             Ireland   83203.39468
# ...

# %%
df[['Value']].plot()
# Out:
# <Axes: >

# %%
df[['2018']].plot()
# Out:
# <Axes: >

# %%
df.plot(kind = 'scatter', x = 'Value', y = '2018')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='Value', ylabel='2018'>

# %%
pd.plotting.scatter_matrix(df, figsize=(15,15))
# Out:
# array([[<Axes: xlabel='Value', ylabel='Value'>,
#         <Axes: xlabel='2018', ylabel='Value'>,
#         <Axes: xlabel='iq', ylabel='Value'>],
#        [<Axes: xlabel='Value', ylabel='2018'>,
#         <Axes: xlabel='2018', ylabel='2018'>,
#         <Axes: xlabel='iq', ylabel='2018'>],
#        [<Axes: xlabel='Value', ylabel='iq'>,
#         <Axes: xlabel='2018', ylabel='iq'>,
#         <Axes: xlabel='iq', ylabel='iq'>]], dtype=object)

# %% [markdown]
# #Correlation measures the relationship between two variables.
# * Values Between -1 and 1
#  * 1 = there is a perfect linear relationship between the variables
#  * 0 = there is no linear relationship between the variables
#  * -1 = there is a perfect negative linear relationship between the variables
#
# **There is an important difference between correlation and causality:**
# * Correlation is a number that measures how closely the data are related
# * Causality is the conclusion that x causes y.
#
# **Correlation Does Not Imply Causality**
#
# * During the summer, the sale of ice cream at a beach increases
# * Simultaneously, drowning accidents also increase as well
# * Does this mean that increase of ice cream sale is a direct cause of increased drowning accidents?

# %%
df.corr()
# Out:
#           Value      2018
# Value  1.000000  0.709689
# 2018   0.709689  1.000000

# %% [markdown]
# Com base nos valores obtidos, pode-se afirmar que existe significativa correlação entre o GDP de 2018 e os valores de BLI por país.

# %% [markdown]
# # Exercício
# Baixe a base de dados de QI por país e investigue:
# 1.   qual o QI médio a nível mundial?
# 2.   qual o QI médio por continente?
# 3.   plote o gráfico de QI por país
# 4.   existe alguma correlação aparente entre QI e BLI ou GDP, investigados nos exemplos anteriores? Use JOIN.
#
# QI - arquivo CSV:<br>
# **https://worldpopulationreview.com/country-rankings/average-iq-by-country**

# %% [markdown]
# **RESOLUÇÃO DO EXERCÍCIO**

# %%
df_QI = pd.read_csv('QI.csv')
df_QI
# Out:
#      place       pop2023  growthRate       area       country cca3 cca2  ccn3  \
# 0      392  1.232945e+08    -0.00530   377930.0         Japan  JPN   JP   392
# 1      158  2.392328e+07     0.00125    36193.0        Taiwan  TWN   TW   158
# 2      702  6.014723e+06     0.00653      710.0     Singapore  SGP   SG   702
# 3      344  7.491609e+06     0.00037     1104.0     Hong Kong  HKG   HK   344
# 4      156  1.425671e+09    -0.00015  9706961.0         China  CHN   CN   156
# ..     ...           ...         ...        ...           ...  ...  ...   ...
# 194    132  5.986820e+05     0.00933     4033.0    Cape Verde  CPV   CV   132
# 195    320  1.809203e+07     0.01391   108889.0     Guatemala  GTM   GT   320
# 196    694  8.791092e+06     0.02154    71740.0  Sierra Leone  SLE   SL   694
# 197    430  5.418377e+06     0.02182   111369.0       Liberia  LBR   LR   430
# 198    524  3.089659e+07     0.01143   147181.0         Nepal  NPL   NP   524
#
# ...

# %%
df_QI.describe()
# Out:
#             place       pop2023  growthRate          area        ccn3  \
# count  199.000000  1.990000e+02  199.000000  1.990000e+02  199.000000
# mean   423.361809  4.037817e+07    0.010458  6.814978e+05  423.361809
# std    254.658277  1.482204e+08    0.012681  1.893449e+06  254.658277
# min      4.000000  1.704400e+04   -0.074480  3.290000e+01    4.000000
# 25%    199.500000  1.957945e+06    0.003225  2.052150e+04  199.500000
# 50%    418.000000  8.958960e+06    0.008790  1.176000e+05  418.000000
# 75%    642.500000  2.959938e+07    0.018380  5.205440e+05  642.500000
# max    894.000000  1.428628e+09    0.049800  1.709824e+07  894.000000
#
#          landAreaKm       density     densityMi        Rank          iq  \
# count  1.990000e+02    199.000000    199.000000  199.000000  199.000000
# mean   6.529235e+05    356.388599    923.046469  102.125628   82.031256
# std    1.816259e+06   1703.130877   4411.108970   60.845634   13.347645
# ...

# %%
df_QI['region'].unique()
# Out:
# array(['Asia', 'Europe', 'North America', 'Oceania', 'South America',
#        'Africa'], dtype=object)

# %%
print('Asia',df_QI[ df_QI['region'] == 'Asia']['iq'].mean())
print('Europe',df_QI[ df_QI['region'] == 'Europe']['iq'].mean())
print('South America',df_QI[ df_QI['region'] == 'South America']['iq'].mean())
print('North America',df_QI[ df_QI['region'] == 'North America']['iq'].mean())
print('Oceania',df_QI[ df_QI['region'] == 'Oceania']['iq'].mean())
print('Africa',df_QI[ df_QI['region'] == 'Africa']['iq'].mean())
# Out:
# Asia 85.79819999999998
# Europe 94.93785714285714
# South America 83.78333333333335
# North America 78.45275862068965
# Oceania 86.94142857142857
# Africa 68.25403846153847

# %%
df_QI[ df_QI['region'] == 'North America']
# Out:
#      place      pop2023  growthRate       area  \
# 15     124   38781291.0     0.00850  9984670.0
# 20     304      56643.0     0.00314  2166086.0
# 28     840  339996563.0     0.00505  9372610.0
# 45      60      64069.0    -0.00179       54.0
# 49      52     281995.0     0.00128      430.0
# 66     188    5212173.0     0.00605    51100.0
# 69     484  128455567.0     0.00746  1964375.0
# 74      44     412623.0     0.00644    13943.0
# 82     780    1534937.0     0.00254     5130.0
# 85     796      46062.0     0.00786      948.0
# 95     192   11194449.0    -0.00158   109884.0
# 101    136      69310.0     0.00879      264.0
# 103    332   11724763.0     0.01206    27750.0
# 104    214   11332972.0     0.00928    48671.0
# 106    630    3260314.0     0.00243     8870.0
# 120    308     126183.0     0.00594      344.0
# 123    591    4468087.0     0.01350    75417.0
# 137     92      31538.0     0.00744      151.0
# 146    388    2825544.0    -0.00065    10991.0
# ...

# %%
df_QI[ df_QI['cca3'] == 'BRA']
# Out:
#     place      pop2023  growthRate       area country cca3 cca2  ccn3  \
# 97     76  216422446.0     0.00515  8515767.0  Brazil  BRA   BR    76
#
#            region                     subregion  landAreaKm  density  \
# 97  South America  South America, Latin America   8358140.0  25.8936
#
#     densityMi  Rank     iq  rank
# 97    67.0645     7  83.38    98

# %%
df_QI[['country','iq']].set_index('country').plot(figsize = (15,5))
# Out:
# <Axes: xlabel='country'>

# %%
df = df.join(df_QI[['cca3','iq']].set_index('cca3'))
df
# Out:
#              Country  Value            Country           2018      iq
# FIN          Finland    7.9             Finland   48416.93603  101.20
# ISL          Iceland    7.6             Iceland   57303.06078   98.26
# CHE      Switzerland    7.5         Switzerland   68060.94105   99.24
# DNK          Denmark    7.5             Denmark   55671.16527   97.83
# NLD      Netherlands    7.5         Netherlands   56328.94114  100.74
# LUX       Luxembourg    7.4          Luxembourg  113337.42050   99.87
# SWE           Sweden    7.3              Sweden   53208.88436   97.00
# NOR           Norway    7.3              Norway   65510.58527   97.13
# NZL      New Zealand    7.3         New Zealand   41005.42087   98.57
# DEU          Germany    7.3             Germany   53074.54012  100.74
# ISR           Israel    7.2              Israel   39919.16965   92.43
# AUT          Austria    7.2             Austria   55454.68929   98.38
# ...

# %%
df['iq'].plot()
# Out:
# <Axes: >

# %%
df.corr()
# Out:
#           Value      2018        iq
# Value  1.000000  0.709689  0.603859
# 2018   0.709689  1.000000  0.571089
# iq     0.603859  0.571089  1.000000
